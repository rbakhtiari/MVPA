# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure()
ax1 = fig.add_subplot(111)
def animate(i):
    graph_data = open('C:\MobiliT\example.txt','r').read()
    lines = graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) >1:
            x,y = line.split(',')
            xs.append(x)
            ys.append(y)
    ax1.clear()
    ax1.plot(xs,ys)
    
ani = animation.FuncAnimation(fig,animate,interval=1000)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(111)

graph_data = open('C:\MobiliT E-Textile\F000_L_Baseline_116.txt','r').read()
lines = graph_data.split('\n')
IntCnt = []
BLECnt = []
Data = []
for line in lines:
    if len(line) >1:
        x,y,z = line.split('\t')
        IntCnt.append(x)
        BLECnt.append(y)
        Data.append(z)

ax1.plot(Data)

# %%
len(BLECnt)
# Out:
# 13500

# %%
Data[-5:]

# %%
int(150/4)
# Out:
# 37
